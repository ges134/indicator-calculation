# %%
import numpy as np
import matplotlib.pyplot as plt
import textalloc as ta

# this changes the default date converter for better interactive plotting of dates:
plt.rcParams['date.converter'] = 'concise'

# %%
plt.clf()

plt.rcParams.update({'font.size': 14})

eigen_vectors = [
  [-0.5104133039163357,0.05912354208611089,0.34328005575308074,-0.04210004567115914,-0.3256987845274617,-0.1975385935266521,0.3643643358479253,-0.5818131074666476],
  [0.20151140836717038,0.4104401172718641,-0.47705533882447443,-0.39151113609069493,0.05239058389044891,-0.606534392197948,0.1674834421664466,-0.10672324418110472],
  [-0.4705217776988349,0.34515660301127626,0.019168123792950298,0.23016218227336943,-0.3250174889536272,-0.25476302776626314,-0.09155649400214763,0.6536137765943599],
  [0.5216801053121204,0.05961375360538629,0.20261286287621177,0.32729156507065393,-0.2131304154711705,-0.01906413622146501,0.698128427423189,0.20725108170564385],
  [-0.24531066926879025,0.3842838672975818,-0.3097112679255719,0.5518824050323371,0.5187492837553418,0.20230714135104136,0.20470806146039106,-0.19929610419722152],
  [0.3728443869186861,0.37725375412765966,0.32886058324951084,0.38605989958314935,-0.13066767281421077,-0.235239068391182,-0.5418477378097248,-0.30897363620980267],
  [-0.03145658589171435,0.2870159258480029,0.6373165407465464,-0.3410890440948052,0.5831054192126236,-0.058762488524015145,0.0889811650279793,0.20672596523077885],
  [0.07176878016183467,0.5770474931276092,-0.05398974017508318,-0.33896024354529547,-0.3375319189674151,0.6542998278659082,-0.00015957980637728455,-0.04494894423529829]
]

plt.figure(figsize=(7, 7))
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

for i, contribution in enumerate(eigen_vectors):
    plt.plot(contribution[0], contribution[1], 'r.')
    plt.plot([0, contribution[0]], [0, contribution[1]], 'r-')

plt.grid(True)
plt.show()
